# %% [markdown]
# # LOC, ILOC | GROUPBY

# %% [markdown]
# Loc = lable based selection

# %%
import pandas as pd

# %%
data =pd.read_csv("netflix_data.csv")

# %%
data.head(n=10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   duration      7787 non-null   int64
#  9   description   7787 non-null   object
#  10  genre         7787 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 669.3+ KB

# %%
data.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
data["type"].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
data.loc[:,"type"]
# Out:
# 0       TV Show
# 1         Movie
# 2         Movie
# 3         Movie
# 4         Movie
#          ...
# 7782      Movie
# 7783      Movie
# 7784      Movie
# 7785    TV Show
# 7786      Movie
# Name: type, Length: 7787, dtype: object

# %%
data.loc[:,["type","country"]]
# Out:
#          type         country
# 0     TV Show          Brazil
# 1       Movie          Mexico
# 2       Movie       Singapore
# 3       Movie   United States
# 4       Movie   United States
# ...       ...             ...
# 7782    Movie          Sweden
# 7783    Movie           India
# 7784    Movie             NaN
# 7785  TV Show       Australia
# 7786    Movie  United Kingdom
#
# [7787 rows x 2 columns]

# %%
data.loc[:,["type"]].value_counts()
# Out:
# type
# Movie      5377
# TV Show    2410
# dtype: int64

# %%
data.sort_values("duration")
# Out:
#      show_id     type                         title                director  \
# 4954   s4955  TV Show      Power Rangers: Megaforce                     NaN
# 4369   s4370  TV Show                   Mystery Lab                     NaN
# 4370   s4371  TV Show  Mystery Science Theater 3000                     NaN
# 4373   s4374  TV Show             Mystic Pop-up Bar                     NaN
# 4375   s4376  TV Show               Mystic Whispers                     NaN
# ...      ...      ...                           ...                     ...
# 5108   s5109    Movie               Raya and Sakina           Hussein Kamal
# 3694   s3695    Movie            Lock Your Girls In       Fouad El-Mohandes
# 4490   s4491    Movie                No Longer kids         Samir Al Asfory
# 6850   s6851    Movie        The School of Mischief  Houssam El-Din Mustafa
# 957     s958    Movie    Black Mirror: Bandersnatch                     NaN
#
# ...

# %%
data.sort_values("release_year")
# Out:
#      show_id     type                                          title  \
# 4867   s4868  TV Show              Pioneers: First Women Filmmakers*
# 6117   s6118    Movie                           The Battle of Midway
# 4960   s4961    Movie                                 Prelude to War
# 7679   s7680    Movie                WWII: Report from the Aleutians
# 7342   s7343    Movie  Undercover: How to Operate Behind Enemy Lines
# ...      ...      ...                                            ...
# 4173   s4174  TV Show                                        Monarca
# 3822   s3823  TV Show                                          Lupin
# 980     s981  TV Show                                   Bling Empire
# 1285   s1286    Movie                                       Charming
# 4468   s4469  TV Show    Night Stalker: The Hunt for a Serial Killer
#
#             director                                               cast  \
# ...

# %%
data.sort_values(["duration","release_year"])
# Out:
#      show_id     type                                title  \
# 4867   s4868  TV Show    Pioneers: First Women Filmmakers*
# 4866   s4867  TV Show  Pioneers of African-American Cinema
# 4216   s4217  TV Show     Monty Python's Fliegender Zirkus
# 1949   s1950  TV Show                             El Chavo
# 4478   s4479  TV Show                        Ninja Hattori
# ...      ...      ...                                  ...
# 5108   s5109    Movie                      Raya and Sakina
# 3694   s3695    Movie                   Lock Your Girls In
# 4490   s4491    Movie                       No Longer kids
# 6850   s6851    Movie               The School of Mischief
# 957     s958    Movie           Black Mirror: Bandersnatch
#
#                                                director  \
# 4867                                                NaN
# 4866  Oscar Micheaux, Spencer Williams, Richard E. N...
# 4216                                                NaN
# ...

# %%
data.sort_values(["release_year"],ascending=False)
# Out:
#      show_id     type                                              title  \
# 2327   s2328  TV Show                                  Gabby's Dollhouse
# 4468   s4469  TV Show        Night Stalker: The Hunt for a Serial Killer
# 2753   s2754  TV Show                             History of Swear Words
# 5103   s5104    Movie  Ratones Paranoicos: The Band that Rocked Argen...
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# ...      ...      ...                                                ...
# 7616   s7617    Movie                 Why We Fight: The Battle of Russia
# 7342   s7343    Movie      Undercover: How to Operate Behind Enemy Lines
# 6117   s6118    Movie                               The Battle of Midway
# 4960   s4961    Movie                                     Prelude to War
# 4867   s4868  TV Show                  Pioneers: First Women Filmmakers*
#
#                              director  \
# 2327                              NaN
# ...

# %%
data.sort_values(["duration","release_year"],ascending=[True,False])
# Out:
#      show_id     type                          title                director  \
# 980     s981  TV Show                   Bling Empire                     NaN
# 2327   s2328  TV Show              Gabby's Dollhouse                     NaN
# 2672   s2673  TV Show  Headspace Guide to Meditation                     NaN
# 2753   s2754  TV Show         History of Swear Words                     NaN
# 3822   s3823  TV Show                          Lupin                     NaN
# ...      ...      ...                            ...                     ...
# 5108   s5109    Movie                Raya and Sakina           Hussein Kamal
# 3694   s3695    Movie             Lock Your Girls In       Fouad El-Mohandes
# 4490   s4491    Movie                 No Longer kids         Samir Al Asfory
# 6850   s6851    Movie         The School of Mischief  Houssam El-Din Mustafa
# 957     s958    Movie     Black Mirror: Bandersnatch                     NaN
#
# ...

# %%
array=data.loc[1,"cast"].split(", ")
print(array)
print(len(array))
# Out:
# ['Demián Bichir', 'Héctor Bonilla', 'Oscar Serrano', 'Azalia Ortiz', 'Octavio Michel', 'Carmen Beato']
# 6

# %%
cast_array=data.loc[2 ,"cast"].split(", ")
print(cast_array)
print(len(cast_array))
# Out:
# ['Tedd Chan', 'Stella Chung', 'Henley Hii', 'Lawrence Koh', 'Tommy Kuan', 'Josh Lai', 'Mark Lee', 'Susan Leong', 'Benjamin Lim']
# 9

# %%
def count_cast():
    cast_array=len(data.loc[1:2,"cast"].split(", "))
    return cast_array

# %%
data.loc[data["title"]="Kota Factory"]

# %%
data

# %%
def split_comma(df):
    df = str(df)
    if df =="NaN":
        return 0
    return len(df.split(", "))

# %%
df["num_of_cast"] = df["cast"].apply(split_comma)

# %%
df_nd.groupby("type")["genre"].value_counts()
